# %% [markdown]
# # ARIMA Model

# %%
import os
import sys

import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
import torch

src_path = os.path.abspath(os.path.join('../../..'))
if src_path not in sys.path:
    sys.path.append(src_path)

from src.models.arima import MultiARIMA
from src.utils.datasets import HSMD

# %%
dataset = HSMD('../../../data/HSMD', stocks=['aapl'])

# %%
generator = torch.Generator().manual_seed(1)
train_size = int(len(dataset) * 0.9)
test_size = len(dataset) - train_size
train_set, test_set = torch.utils.data.random_split(dataset, [train_size, test_size], generator=generator)

# %%
predictions = []
history = [x for x in train_set]
for window in test_set:
    model = MultiARIMA(features=[""], history, order=(5, 1, 0))
    fit = model.fit()
    output = fit.forecast()
    predictions.append(y_hat)
    history.append(window)
    print('predicted=%f, expected=%f' % (y_hat, window))
# Out:
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# (7, 6)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3c/dx97b2j51531g6lzn36pdzh80000gn/T/ipykernel_36282/3377734360.py in <module>
#       5 history = [x for x in train_set]
#       6 for window in test_set:
# ----> 7     model = ARIMA(history, order=(5, 1, 0))
#       8     fit = model.fit()
#       9     output = fit.forecast()
#
# ~/ws/StockBot/stockbotenv/lib/python3.9/site-packages/statsmodels/tsa/arima/model.py in __init__(self, endog, exog, order, seasonal_order, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     130         # this criteria. Instead, we'll just make sure that the parameter
#     131         # estimates from those methods satisfy the criteria.)
# --> 132         self._spec_arima = SARIMAXSpecification(
#     133             endog, exog=exog, order=order, seasonal_order=seasonal_order,
#     134             trend=trend, enforce_stationarity=None, enforce_invertibility=None,
#
# ~/ws/StockBot/stockbotenv/lib/python3.9/site-packages/statsmodels/tsa/arima/specification.py in __init__(self, endog, exog, order, seasonal_order, ar_order, diff, ma_order, seasonal_ar_order, seasonal_diff, seasonal_ma_order, seasonal_periods, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     452         if (validate_specification and not faux_endog and
#     453                 self.endog.ndim > 1 and self.endog.shape[1] > 1):
# --> 454             raise ValueError('SARIMAX models require univariate `endog`. Got'
#     455                              ' shape %s.' % str(self.endog.shape))
#     456
#
# ValueError: SARIMAX models require univariate `endog`. Got shape (1075, 7, 6).
